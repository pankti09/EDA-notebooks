# %%
import sklearn 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
iris=pd.read_csv('Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(iris.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
print(iris.shape)
# Out:
# (150, 6)

# %%
print(iris.columns[0])
# Out:
# Id

# %%
iris["Species"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
iris.plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm')

# %%
sns.set_style('whitegrid');
sns.FacetGrid(iris, hue='Species',size=7).map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend();
plt.show()

# %%
sns.pairplot(iris,hue="Species")

# %%
sns.pairplot(iris, hue="Species", palette="husl")

# %%
sns.pairplot(iris, hue="Species", markers=["o", "s", "D"])

# %%
sns.pairplot(iris, vars=["SepalWidthCm", "SepalLengthCm"])

# %%
 g = sns.pairplot(iris,x_vars=["SepalWidthCm", "SepalLengthCm"],y_vars=["PetalWidthCm", "PetalLengthCm"])

# %%
sns.pairplot(iris, diag_kind="kde")

# %%
sns.pairplot(iris, kind="reg")

# %%
 sns.pairplot(iris, diag_kind="kde", markers="+", plot_kws=dict(s=50, edgecolor="b", linewidth=1),diag_kws=dict(shade=True))
